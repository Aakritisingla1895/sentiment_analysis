# %%
import pandas as pd
import numpy as np
import networkx as nx
import matplotlib as plt
import graphviz
from pprint import pprint
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import sent_tokenize, word_tokenize, WordPunctTokenizer, TweetTokenizer
from nltk import pos_tag

from sklearn.metrics import classification_report
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV, train_test_split, cross_val_score, cross_val_predict
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import MultinomialNB, BernoulliNB

# %matplotlib inline

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Using cached https://files.pythonhosted.org/packages/94/cd/7b37f2b658995033879719e1ea4c9f171bf7a14c16b79220bd19f9eda3fe/graphviz-0.13-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.13

# %%
data_path = 'E:/AI projects/Sentiment Analysis/text_emotion.csv'

# %%
df_init = pd.read_csv(data_path)

# %%
df_init
# Out:
#          tweet_id   sentiment           author  \
# 0      1956967341       empty       xoshayzers
# 1      1956967666     sadness        wannamama
# 2      1956967696     sadness        coolfunky
# 3      1956967789  enthusiasm      czareaquino
# 4      1956968416     neutral        xkilljoyx
# 5      1956968477       worry    xxxPEACHESxxx
# 6      1956968487     sadness         ShansBee
# 7      1956968636       worry         mcsleazy
# 8      1956969035     sadness      nic0lepaula
# 9      1956969172     sadness       Ingenue_Em
# 10     1956969456     neutral       feinyheiny
# 11     1956969531       worry     dudeitsmanda
# 12     1956970047     sadness         Danied32
# 13     1956970424     sadness          Samm_xo
# 14     1956970860    surprise     okiepeanut93
# 15     1956971077     sadness           Sim_34
# 16     1956971170        love     poppygallico
# 17     1956971206     sadness  brokenangel1982
# 18     1956971473       worry            LCJ82
# 19     1956971586     sadness          cleepow
# 20     1956971981       worry    andreagauster
# 21     1956972097         fun    schiz0phren1c
# 22     1956972116     neutral            jansc
# 23     1956972270       worry        sweet8181
# 24     1956972359     sadness   xamountoftruth
# 25     1956972444       worry       jomama6881
# 26     1956972557     sadness       LilithGaea
# 27     1956972884       worry      oONEPTUNEOo
# 28     1956973598     sadness  username_origin
# 29     1956973690       worry    catchtheapple
# ...           ...         ...              ...
# 39970  1753904518        love        lisa24270
# 39971  1753904526  enthusiasm       Freakonomy
# 39972  1753904626   happiness        tchvinkle
# 39973  1753904668         fun       Mirunnetje
# 39974  1753904674        love    DivasMistress
# 39975  1753904682       empty        patphelan
# 39976  1753904748     neutral   CharlotteMcFLY
# 39977  1753904799    surprise         Ocnarf10
# 39978  1753904868       worry  theknickermafia
# 39979  1753904911    surprise        fadedmoon
# 39980  1753904912   happiness           RyanJL
# 39981  1753904919   happiness     DominiqueGoh
# 39982  1753905020     neutral         2str20lt
# 39983  1753905073     neutral         ABZQuine
# 39984  1753905113    surprise        kanjigirl
# 39985  1753905121   happiness     MizFitOnline
# 39986  1753905153   happiness           sue_jr
# 39987  1753918809   happiness          njohari
# 39988  1753918818   happiness  RachellSmithles
# 39989  1753918822        love            Rellz
# 39990  1753918829     neutral          kdpaine
# 39991  1753918846     neutral         x0159432
# 39992  1753918881     neutral      _Alectrona_
# 39993  1753918892     neutral       bushidosan
# 39994  1753918900   happiness     courtside101
# 39995  1753918954     neutral    showMe_Heaven
# 39996  1753919001        love         drapeaux
# 39997  1753919005        love         JenniRox
# 39998  1753919043   happiness         ipdaman1
# 39999  1753919049        love      Alpharalpha
#
#                                                  content
# 0      @tiffanylue i know  i was listenin to bad habi...
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 3                   wants to hang out with friends SOON!
# 4      @dannycastillo We want to trade with someone w...
# 5      Re-pinging @ghostridah14: why didn't you go to...
# 6      I should be sleep, but im not! thinking about ...
# 7                   Hmmm. http://www.djhero.com/ is down
# 8                @charviray Charlene my love. I miss you
# 9             @kelcouch I'm sorry  at least it's Friday?
# 10                                      cant fall asleep
# 11                               Choked on her retainers
# 12     Ugh! I have to beat this stupid song to get to...
# 13     @BrodyJenner if u watch the hills in london u ...
# 14                                          Got the news
# 15         The storm is here and the electricity is gone
# 16                                  @annarosekerr agreed
# 17     So sleepy again and it's not even that late. I...
# 18     @PerezHilton lady gaga tweeted about not being...
# 19     How are YOU convinced that I have always wante...
# 20     @raaaaaaek oh too bad! I hope it gets better. ...
# 21     Wondering why I'm awake at 7am,writing a new s...
# 22     No Topic Maps talks at the Balisage Markup Con...
# 23     I ate Something I don't know what it is... Why...
# 24     so tired and i think i'm definitely going to g...
# 25     On my way home n having 2 deal w underage girl...
# 26     @IsaacMascote  i'm sorry people are so rude to...
# 27     Damm servers still down  i need to hit 80 befo...
# 28     Fudge.... Just BS'd that whole paper.... So ti...
# 29         I HATE CANCER. I HATE IT I HATE IT I HATE IT.
# ...                                                  ...
# 39970                               @Rtib happy birthday
# 39971   @SarahSaner Hey Sarah! Hws u? Hope u remember me
# 39972  @acchanosaurus good luck chan! gue kmrn bawa b...
# 39973  good morning/midday nation!  FORMULA ONE IN ON...
# 39974  to my pretty lady @nikkiwoods HAPPY MOTHER'S D...
# 39975    @lexia Or even listen to Susan's green policies
# 39976                     right. coursework now. PROMISE
# 39977                        @BuddingGenius you dont say
# 39978  @givemestrength bloody Feds, they lost last st...
# 39979               @prinsezha awesome. Wha'dya get her?
# 39980  Sitting in Gatwick- going home for a week! can...
# 39981            @maynaseric good luck with your auction
# 39982  hey guys, if you have something to ask, just a...
# 39983  @Astronick not really just leaving flat now, o...
# 39984                      @iscreamshinki Oh that's why.
# 39985  @McMedia husband is golfing &amp; the Toddler ...
# 39986  going to watch boy in the striped pj's hope i ...
# 39987  gave the bikes a thorough wash, degrease it an...
# 39988  had SUCH and AMAZING time last night, McFly we...
# 39989  His snoring is so annoying n it keeps me from ...
# 39990  @shonali I think the lesson of the day is not ...
# 39991  @lovelylisaj can you give me the link for the ...
# 39992  @jasimmo Ooo showing of your French skills!! l...
# 39993  @sendsome2me haha, yeah. Twitter has many uses...
# 39994                      Succesfully following Tayla!!
# 39995                                   @JohnLloydTaylor
# 39996                     Happy Mothers Day  All my love
# 39997  Happy Mother's Day to all the mommies out ther...
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
# 39999  @mopedronin bullet train from tokyo    the gf ...
#
# [40000 rows x 4 columns]

# %%
df_init.groupby('sentiment')['content'].count().sort_values()
# Out:
# sentiment
# anger          110
# boredom        179
# enthusiasm     759
# empty          827
# hate          1323
# relief        1526
# fun           1776
# surprise      2187
# love          3842
# sadness       5165
# happiness     5209
# worry         8459
# neutral       8638
# Name: content, dtype: int64

# %%
emotions_set = set(df_init['sentiment'])

# %%
emotions_set
# Out:
# {'anger',
#  'boredom',
#  'empty',
#  'enthusiasm',
#  'fun',
#  'happiness',
#  'hate',
#  'love',
#  'neutral',
#  'relief',
#  'sadness',
#  'surprise',
#  'worry'}

# %%
keep_emotions_list = [
    'anger',
#     'boredom',
#     'empty',
#     'enthusiasm',
#     'fun',
    'happiness',
#     'hate',
#     'love',
#     'neutral',
#     'relief',
    'sadness',
    'surprise',
#     'worry'
]

# %%
df = df_init[df_init['sentiment'].isin(keep_emotions_list)]

# %%
df
# Out:
#          tweet_id  sentiment           author  \
# 1      1956967666    sadness        wannamama
# 2      1956967696    sadness        coolfunky
# 6      1956968487    sadness         ShansBee
# 8      1956969035    sadness      nic0lepaula
# 9      1956969172    sadness       Ingenue_Em
# 12     1956970047    sadness         Danied32
# 13     1956970424    sadness          Samm_xo
# 14     1956970860   surprise     okiepeanut93
# 15     1956971077    sadness           Sim_34
# 17     1956971206    sadness  brokenangel1982
# 19     1956971586    sadness          cleepow
# 24     1956972359    sadness   xamountoftruth
# 26     1956972557    sadness       LilithGaea
# 28     1956973598    sadness  username_origin
# 36     1956976312    sadness          amy__xx
# 40     1956977084  happiness         ktierson
# 47     1956979150    sadness           rionne
# 59     1956982383    sadness           Ameeee
# 61     1956982576    sadness       kShadhavar
# 62     1956982605    sadness           Diyeni
# 63     1956983160    sadness        crittyjoy
# 64     1956983171    sadness          paulyum
# 67     1956983690    sadness       Trishalove
# 69     1956983874  happiness             joia
# 77     1956985535  happiness       quarrygirl
# 80     1956985764    sadness          Samm_xo
# 82     1956986211    sadness    metaphysical1
# 84     1956986767    sadness          AshLaws
# 95     1956989514    sadness      yellowduckx
# 96     1956989526    sadness          KaKuBby
# ...           ...        ...              ...
# 39927  1753903203  happiness          macmuso
# 39933  1753903325  happiness   LinneaBjorken_
# 39939  1753903509    sadness       wonder_nat
# 39940  1753903552  happiness    aymanelhattab
# 39942  1753903593   surprise        marisa_mm
# 39947  1753903784   surprise      marcelbooth
# 39949  1753903798  happiness           Sion71
# 39950  1753903814  happiness      taylormcfly
# 39952  1753903881  happiness          catiams
# 39954  1753903927   surprise        yandrasap
# 39958  1753904142  happiness  Custardcuppcake
# 39961  1753904185  happiness  joseph_ottorino
# 39963  1753904324  happiness   HanaStephenson
# 39964  1753904357  happiness          Kiaroux
# 39965  1753904398    sadness           t33r4n
# 39966  1753904399  happiness     smileshutter
# 39967  1753904448  happiness      linnetwoods
# 39968  1753904494  happiness       TwangTwong
# 39972  1753904626  happiness        tchvinkle
# 39977  1753904799   surprise         Ocnarf10
# 39979  1753904911   surprise        fadedmoon
# 39980  1753904912  happiness           RyanJL
# 39981  1753904919  happiness     DominiqueGoh
# 39984  1753905113   surprise        kanjigirl
# 39985  1753905121  happiness     MizFitOnline
# 39986  1753905153  happiness           sue_jr
# 39987  1753918809  happiness          njohari
# 39988  1753918818  happiness  RachellSmithles
# 39994  1753918900  happiness     courtside101
# 39998  1753919043  happiness         ipdaman1
#
#                                                  content
# 1      Layin n bed with a headache  ughhhh...waitin o...
# 2                    Funeral ceremony...gloomy friday...
# 6      I should be sleep, but im not! thinking about ...
# 8                @charviray Charlene my love. I miss you
# 9             @kelcouch I'm sorry  at least it's Friday?
# 12     Ugh! I have to beat this stupid song to get to...
# 13     @BrodyJenner if u watch the hills in london u ...
# 14                                          Got the news
# 15         The storm is here and the electricity is gone
# 17     So sleepy again and it's not even that late. I...
# 19     How are YOU convinced that I have always wante...
# 24     so tired and i think i'm definitely going to g...
# 26     @IsaacMascote  i'm sorry people are so rude to...
# 28     Fudge.... Just BS'd that whole paper.... So ti...
# 36     @ether_radio yeah :S i feel all funny cause i ...
# 40     mmm much better day... so far! it's still quit...
# 47     I'm having a problem with my photo here in twi...
# 59     @maternitytees Aww  Onward and upwards now, ya...
# 61     diesel yaris... 70mpg  so sad its not availabl...
# 62     I want to buy this great album but unfortunate...
# 63           @Pokinatcha  in all honesty...pain   blech.
# 64     Ok ... the passengers ... no one is alive ... ...
# 67     @vincew @stefanyngo  i fell asleep on the beac...
# 69     So great to see Oin &amp; Cynthia.  So happy. ...
# 77     @havingmysay  dude, that is my favorite sandwi...
# 80     @RachelLock22 ohh thursday i have exams.. all ...
# 82     @gcrush @nopantsdance i was just thinking abou...
# 84     @artfuldodga I love those 'it'sakey' USB stick...
# 95     @sweeetnspicy hiii im on my ipod...i cant fall...
# 96       dont wanna work 11-830 tomorrow  but i get paid
# ...                                                  ...
# 39927  instant-messaging with two of my favourite con...
# 39933                       Had a great time last night!
# 39939  @watermelon39 haha! And Twitter! Hard though i...
# 39940              @HosamKamel Thanks for the follow man
# 39942  @Rove1974 anychance you can get matthew to giv...
# 39947      @MancunianLee Oh aye.....he rocks, shes horny
# 39949                   @dai_bach daps were the best lol
# 39950      @DebbieFletcher haha i will remember that  xx
# 39952  @sharlynnx ME TOO! please come online *-* hope...
# 39954                           today was interesting...
# 39958  @JamesHancox LOL or maybe it's the tooth fairy...
# 39961  Wow! Up, coffee in hand and already outside.  ...
# 39963  THE VIDEO IS FINALLY DONE WOOOOOOOOOOOOOOOOOOO...
# 39964  Watched Wolverine yesterday ... a spur of the ...
# 39965                         is heading off to the fair
# 39966      the sunset view is SO beautiful from my room!
# 39967  @McMedia Very well thank you! How are you, mor...
# 39968  @muffinwomanxo EH! u dont like retro? tisk tis...
# 39972  @acchanosaurus good luck chan! gue kmrn bawa b...
# 39977                        @BuddingGenius you dont say
# 39979               @prinsezha awesome. Wha'dya get her?
# 39980  Sitting in Gatwick- going home for a week! can...
# 39981            @maynaseric good luck with your auction
# 39984                      @iscreamshinki Oh that's why.
# 39985  @McMedia husband is golfing &amp; the Toddler ...
# 39986  going to watch boy in the striped pj's hope i ...
# 39987  gave the bikes a thorough wash, degrease it an...
# 39988  had SUCH and AMAZING time last night, McFly we...
# 39994                      Succesfully following Tayla!!
# 39998  @niariley WASSUP BEAUTIFUL!!! FOLLOW ME!!  PEE...
#
# [12671 rows x 4 columns]

# %%
text_list = df.content.tolist()

# %%
text_list
# Out:
# ['Layin n bed with a headache  ughhhh...waitin on your call...',
#  'Funeral ceremony...gloomy friday...',
#  "I should be sleep, but im not! thinking about an old friend who I want. but he's married now. damn, &amp; he wants me 2! scandalous!",
#  '@charviray Charlene my love. I miss you',
#  "@kelcouch I'm sorry  at least it's Friday?",
#  'Ugh! I have to beat this stupid song to get to the next  rude!',
#  '@BrodyJenner if u watch the hills in london u will realise what tourture it is because were weeks and weeks late  i just watch itonlinelol',
#  'Got the news',
#  'The storm is here and the electricity is gone',
#  "So sleepy again and it's not even that late. I fail once again.",
#  'How are YOU convinced that I have always wanted you? What signals did I give off...damn I think I just lost another friend',
#  "so tired and i think i'm definitely going to get an ear infection.  going to bed &quot;early&quot; for once.",
#  "@IsaacMascote  i'm sorry people are so rude to you, isaac, they should get some manners and know better than to be so lewd!",
#  "Fudge.... Just BS'd that whole paper.... So tired.... Ugh I hate school.....  time to sleep!!!!!!!!!!!",
#  "@ether_radio yeah :S i feel all funny cause i haven't slept enough  i woke my mum up cause i was singing she's not impressed :S you?",
#  "mmm much better day... so far! it's still quite early. last day of #uds",
#  "I'm having a problem with my photo here in twitter amf!!!...can't see my face!",
#  '@maternitytees Aww  Onward and upwards now, yay! Still sad to leave I bet.',
#  "diesel yaris... 70mpg  so sad its not available in the US. That'd be awesome.",
#  'I want to buy this great album but unfortunately i dont hav enuff funds  its &quot;long time noisy&quot;',
#  '@Pokinatcha  in all honesty...pain   blech.',
#  "Ok ... the passengers ... no one is alive ... they're all dead ... you just don't know it til the end ... then you cry ...",
#  "@vincew @stefanyngo  i fell asleep on the beach and didn't put on enough sunscreen  lol",
#  'So great to see Oin &amp; Cynthia.  So happy.  Dinner was great, cute little place.  Too bad Oin got sick afterwards.',
#  '@havingmysay  dude, that is my favorite sandwich place ever. ummm did you take PICTURES?',
#  '@RachelLock22 ohh thursday i have exams.. all day  what about wednesday ?',
#  '@gcrush @nopantsdance i was just thinking about how excited i am for you guys to move, but then i realized how sad i am to see you go.',
#  "@artfuldodga I love those 'it'sakey' USB sticks. We only have the 4GB in Australia",
#  '@sweeetnspicy hiii im on my ipod...i cant fall asleep',
#  'dont wanna work 11-830 tomorrow  but i get paid',
#  'feels sad coz i wasnt able to play with the guys!!!  http://plurk.com/p/wxiux',
#  "Darn these allergies! I don't like this time of year because of this! I never used to have this problem either",
#  "@cayogial i wanted to come to BZ this summer :/ not so sure anymore... a teacher's life in the summer SUCKS",
#  'I wish she knew what she puts me through..She stole my heart, never gave it back..and occasionally she likes to be like look what I have!',
#  "@neesabear early happy day of birth in case I don't make it! Very tired from therapy today n just taking my medicine!  misshu! Love ya!",
#  'Allergies suck ducks nuts.     &lt;=====8@8=====&gt;',
#  'wonders why her Karma points turned into 0.00.  http://plurk.com/p/wxj54',
#  'Need to pack for CALI CALI! Cannot waittt! Thinking a glass of wine is in order to celebrate my weekend vaca. Still work 2morrow, tho.',
#  'Is miserable  i feel like im gona cry  sux!',
#  "*sigh* I'm going to bed... I just don't feel right anymore...",
#  'Now I am depressed after watching so you think you can dance',
#  "Just cross 'cause I'm stuck twiddling my thumbs now, ugh",
#  'Last day working for the Uni today, sad times',
#  'is still missing her husband.    I really want him home.',
#  'I miss my puppy',
#  '2 days of this month left, and I only have 400MB left on my onpeak downloads.',
#  "@nzdeany I've given up on pizza - kids would never let me have my fav  (the hot ones)",
#  '@BarbSchaefer yearling in pet home died... very sad for their whole family',
#  "@heresmyhello92 We hate change, so of course. We're fans for life. &lt;3 Oh and if we haven't met Rob by then something went horribly wrong.",
#  "well fuck- this new pain med has an odd warning that actually applies to me. i can't take this. -chan is displeased.",
#  'just uploaded my new blog... a painful story about an 80s year old man who cried because he wanted to die... very sad',
#  'I just saw pics from this past Thanksgiving and am sad because Grandma was in them.',
#  "Took a shift tomorrow.    I don't really feel like working right now.",
#  'but now i have no money for a phone',
#  "@Bern_morley where are you? In Bris? I can't hear any thunder",
#  'bec vs fat food   --- winner = fat food  but not this weeknend, ill beat it!',
#  'Too bad the Red Devils.. disappointing to say the least',
#  'I had a dream about a pretty pretty beach and there was no beach when I woke up',
#  '@xdjio Have a 3ware 9650SE, not fast enough for 3x X25-M SSD RAID5. 800Mhz IOP on the HPT. Might try an Adaptec 5405 (1.2Ghz).',
#  'when da heck will the garage man get here I ask you.. WHEN..',
#  '@AlexanderGWhite daaammmnnnnn I do wish I was there.',
#  '@yuki_hime I played up until the latter parts of the voodoo village part co-op until I lost my usual partner',
#  'is a bad friend',
#  '@moggy99 No internet last night; ER was brill, there was a massive explosion at the end of a nearby gas works ER on standby',
#  '@lenje - Still a pity it comes with no lamb though',
#  "@bloomsday16  I'm sorry to hear that. Here is my optimist: Things will get better. For all of us.",
#  'Why am I completing facebook quizzes at this time of the morning... especially a friday morning',
#  'Had to cancel wow for now',
#  "@fairyfroggie But yeah...I'm sad about my &quot;Ravenclaw&quot; account. I love that account to bits.",
#  'took a math test today. The day before the test, the teacher says bring your calculator. Luke was confident. Teacher decided no calcs.',
#  'omg, the concert was awesome, madrigals gave me chills on almost every piece...brooks also called up alumni, but i didnt get to go',
#  'Up late with nothin 2 do.....',
#  'sometimes i wish things could go back to the way they were the beginning of last summer',
#  '@kateisbored I feel the same way, but I guess no matter where you are there will always be memes.',
#  'I Can`t do 30 minutes of Treadmill  but done 30 minutes for today already, gonna do 20 minutes more',
#  "Chillin with the roomies. Can't wait for the zombie CLWN CR. Its gonna be 6-8 weeks",
#  'Cute Malay girl came to seemy room for rent - sadly think it was for her guyfreind   bit misleading and disappointing LOL',
#  '@Gurlstrange EpiCentre Wheelock Place, 250 units &amp; for tourists only. Starting today',
#  "@FoxxFiles aw u can't let me in on the secret!",
#  "@freshypanda Im sorry  I don't think I stick out, at least compared to what I used to look like.",
#  'Everytime I send an email to my coach, I feel a need to practice.   shitty balls.  Lol',
#  "It's pissing me off and not letting me follow ericka",
#  "Is going to sleep not peaceful  wanted to hear him say Good Night but that didn't happen  Good Night everyone....",
#  'my mums trying to make me feel ebtter about stopping voting adn not winning shortstack. i almost cried.',
#  "is thinking so much and i'm at work",
#  "I haven't seen Muffin in two whole days!",
#  "@YumiFujii i'll miss y'all back... give @LesleyBoudy my regards...",
#  'my gap year is going so quick',
#  'Just found mj mouse flats at DJs. Of course there are none left in my size',
#  '@qi_tah oh no.  *hugs*',
#  "@xoshayzers i knoww  things won't be the samee &lt;/3",
#  '@vinylvickxen i kno i doooo!!!!!!!!!! yall partyin with out me',
#  'Going to sleep. Gonna fall asleep playing apps again. Tmrw is going to suck',
#  "I can't believe the Metal Gear Solid song was stolen    I'm so disappointed  http://bit.ly/YKkSu",
#  "@MacZombieRawr  I wish I had Left 4 Dead. But first I'd need something to play it on...",
#  'I spilled my beer all over my leg. Wasted half my beer.  Home now. I met a cute girl. Good conversation.',
#  'my teeth and head hurts',
#  'I HATE rob zombie movies. &amp; the smell of weed. Vommmm.',
#  'no more arrested development. i am sad.',
#  'omg i keep losing followers this is so sad  i want 90 one day....thats my goal ;D',
#  'I feel so deflated. No more doggy.',
#  'I just had to empty my trash on the mac. that was one of THE MOST DIFFICULT things I have ever done in my life. 8,000 pictures are GONE.',
#  'im contacting PAWS Philippines so i can find &quot;tiger&quot; a new owner. im so sad. i love my dog soo much',
#  'just got home! not wanting to read the last chaper of breaking dawn cause i dont want it to be over',
#  'Fuuudge. Movie store is closed',
#  'ALO is so sad and quiet and empty tonight',
#  '@Mona26 Aw where are you headed to? i just cancelled my trip to Aussie',
#  'Sad that Christian Lacroix had to file bankruptcy',
#  'I dont feel good AT ALL. fuckkk',
#  'Have to go to the dreaded DMV tomorrow',
#  'english class! working on interactive orals',
#  "Taylor Swift and Joe Jonas looked really good together. I'm kinda sad they broke up.",
#  'God I just want to sleep.',
#  'Found my book. Starting a real paper-bound journal tonight. Have an annoying zit above my lip. Makes me look like I have herpes',
#  '@RealBlackWidow But but I dun wanna',
#  "@imjustlalayone damn girl I'm so down but ya gotta let me know so I can get my kit together &amp; I got a flyer  Any next weekend? I&quot;M DOWN!",
#  '@JustinOdom dbl booooooo for being sick, flippin blows! ... bahaha i kno i dont have many friends on here either. i feel so lame  haha',
#  'feels sick to my stomach and idkk whyy',
#  "@justintevya - dude i just saw your SF pics. looks like your mini excursion was pretty kick ass! didn't see any sun while i was there tho",
#  "@hello_jodie Um, I was thrown from @JareWolf's van yesterday and had to be taken to the ER",
#  'FB is boring   and i wanna sing RIGHT NOW..! *-*',
#  "@judyrey  The link doesn't work",
#  '@heavenjones ur supposed to be in BK tho',
#  'Oh no!  Nighty night.',
#  "@celldweller Must... have... new music... I won't sleep until you give us Chapter 1... I might die first though...  Hurry!",
#  'my stupid tooooth hurts',
#  '@turnitgrey my computers broken and I broke my laptop so I had to use the phone  ahh still on he cause they fucked up my order.',
#  "I'm awake. Anybody else awake? Wish I lived in the US since all the fun happens when I'm asleep!",
#  '@Penguin_J heehee. i love you! i am tired.',
#  'Morning everyone sorry for going early last night had bad news, felt totally crap   Today is a new day',
#  "how I wish my parents put me into a Chinese school when I was younger. Then, it'll be so much easier for me to get a job...",
#  '@joiskol  being in your room makes me sad.',
#  '@CocktailChic oh f*ck! I completely forgot about Thirsty Thursday! oh. my. gaga. this sucks',
#  'if one people did any wrong, the world blames all the people over there, this is the great world which we are living in!  Shit!',
#  '@MandyAlwaysKnws nope.  they are all sleeping cuz they live on the east coast.',
#  '@meljachin: eww. dislike',
#  '@SuzyDunkley sorry bout the cat,',
#  'missed iron chef',
#  '@thevowel the DS version sucks',
#  'what a bad day',
#  'omg i didnt tweet all that much today.... *sadness*',
#  '@PandaMayhem noooooooooooo i just look at a lot of pictures   lol lol',
#  '@CrazyBallerina Not really sleepy ...bored is the right word ... again not much work',
#  'went to the cd store to search for the cd. But',
#  'I miss my mom..  &quot;May angels lead you in&quot;',
#  '@chocolovere i feel the same way every day',
#  "Can't sleep. Sucks. The one day i have to sleep in and i have to get up and go shopping with mom. Ugh.",
#  'Sleppytime. Really missing my godfather right now. Love you Wayne',
#  'So have a headache right now and it sucks',
#  "@jwray12 Lakers, baby Lakers!! I'll miss the game tmwr. I have to work  you'll have to keep me posted please",
#  'comfort food of the day: pan mee. though, it didnt taste any good..',
#  'misses my baby.',
#  "I'm poorly and can't sleep",
#  'has work tom.',
#  "today we say goodbye to the second good friend in a week from dmp  but at least the sun is shinning and I'm definately NOT working this pm",
#  "fuckin'm transtelecom",
#  '@ModelTheany  tee we beefin....what was u supposed to do before leavin????',
#  'Sometimes the things you say hurt the ones you love most unintentionally.  And you can never ever take it back or fix it.',
#  '@nickkk_ that sucks!',
#  'Having Fever  dont feel to work',
#  "missing @MeLDiBiAsE...6 days can't pass quick enough",
#  'Working from home today, my back is killing me  Doctor and then physio after later today.',
#  '@ddlovato demi, just say hi to me and it`s enough. just replay to me please  love you so much!!!',
#  'Missing you all deeply',
#  '@mrssunshine96 big now!!! Vanessa is going to be 3 in September, its going by so fast!  its hard cuz Im workin so much, I miss out on alot',
#  "@Ravels sniff sniff  take care ravels! Hopefully we'll be chatting again soon. In the mean time, I'll HELLA miss you.",
#  "I don't want her to leave..",
#  'good lord, just seen the agency work for our upcoming Open Day. Money for Jam',
#  "Working   But it's Fridaaaayyyyy",
#  "@KaliyahPjones lmao...thats sad, kinda discourages me 4rom goin if the shit's wack",
#  "Got home from work @ 9:45 and JUST finished cleaning. Now I need to eat dinner and don't know what I want!!  Ugh...oh well. Might not eat.",
#  '@WillyNorthpole I wish I was there',
#  'I miss my little Batty, she was only 3 months old when she got sick, she was always so fun and full of life &lt;3 Even at the very end...',
#  'morning again! I hate mornings. So offensive!',
#  'bed bed bed @samuelasanders do you never answer texts anymore?  I thought of you the other day and sent one but never heard back. Sad day',
#  "@brianshead waah. We're no longer your peeps.",
#  "@angelica_yo LOL wow dawg doesn't sound like you're playing!  I feel bad now haha",
#  'Extremly deep',
#  'My little foster kittens are getting big...chubba and Winston are going 2 b missed when they get amazing homes.',
#  "@MariusLT I'm sorry about your bad driving experiences.",
#  'Already misses @CMontecillo',
#  "@fiercebanana there's relisting fees when you don't complete a sale?  that sucks!",
#  "Gutted that the bathroom still isn't free- early work isn't going to happen  . And I need the loo!",
#  '@astynes Me too.  Wonder if Mnet will show it...',
#  'thank you @ddlovato (: cant wait!!!! ummm btw ima crash still sick',
#  'First my work computer, now my home laptop is fucked.',
#  "@joek949 It's depressing I'm stuck inside all day",
#  'i hate being sick. i miss @cynthiasheree @lucyowns and @larilync',
#  'Getting ready for school - second maths test today  also its my last day of 3rd year!! Next week i will officially be in 4th year',
#  'Woke Up,I Wanna Stay In My bed',
#  'Upsidedown tomato plants died!',
#  "@ddlovato Caan't Iht Be Earlier? ICant Wait That Long.  Ahar. (:",
#  "Friday yay!! And a bonus, don't have to drive to Wales tonight.  Athough will miss kitten cuddles and going for a ride",
#  'I cant use my blackberry today. This sucks.',
#  '@prncsztalia why do you hate me!?',
#  'http://twitpic.com/663vr - Wanted to visit the animals but we were too late',
#  '#jonaswebcast i just missed it!!!!',
#  "So exhausted..can't sleep. I don't like these nights",
#  "i'm gonna miss all the live Comet action tomorrow! i have to go take care of my cousins and they don't have access to the interwebz",
#  'lol i cant drink!!',
#  "if bill compton has wii, why can't he have twitter?",
#  '@NothinButSin sorry to hear that.',
#  "Just found out I can't drink at this bar! Booo missing e1 at palomino's! No cheers sad face",
#  "Packing  I don't like it..",
#  'finished a whole box of ice cream',
#  'Ok, other then my shoe, the club is cool. Its fun, and its poppin except 4 the ppl tryna dance wit me',
#  '@o0hemmy lol hi emmy, latin would help me study for the aptitude tests to get into grad school ;\\ thats why i wanna take it',
#  '@chrisontv88 btw I am not a wimp',
#  "@queenbmakeup i can't add you on myspace girly  it asks for a last name and email",
#  "I don't wanna go back to work   sleepy time.",
#  "http://bit.ly/3W9w1  NOOOO! he goes for Orlando! OMG  I'm gonna CRY!!!!!!!!",
#  '@MyCakesRock  AAAAAAHHHHHHHH !!!!!  SOOOOOOOO SWEEEEEEET !!!!!!  I miss that age ..... SOOOO MUCH !',
#  'Just saw a fox!  as i was getting on the freeway... I hope it goes home',
#  'recapping on britains got talent. britain seems more talented than america',
#  "@johnpopham Morning John, yes I do, however I have a diary clash and sadly can't attend!",
#  'I miss my friend',
#  'Yea i just saw this really sad commercial',
#  'Hmmm. Using TinyTwitter on a small non-touch screen is really not much fun',
#  'Hates having to sleep alone',
#  "I loved johnny carson now I'm going to hate seeing jay leno go",
#  "even though everyone wanted to do a newish song and our teacher agreed :S old grumpy doesn't like us happy  haha",
#  '@razitul ya. i was suffering the whole day yesterday. met dentist and feel a bit better. i still look like rocky balboa though',
#  'FINALLY...the internet is up. The server is down in Phoenix and it was fucked up.',
#  "I didn't get a callback for the play I cried...  oh well I guess it's back to being a techie..",
#  '@UniqueMakis Awesome! Wish I could fly out to see her',
#  "@lunafactor I kinda wish I went with you now!.. I can't fall asleep",
#  '@Dakshinamurti Not yet... sorry',
#  'FALL ASLEEP ON ME AGAIN  But I know how it feels now LOL. Drag Me To Hell tonight! Quite excited',
#  'someone take me to LA  I NEED TO SEE THE LEMON TREE',
#  "um... so I don't think my text msgs have a &quot;subject line&quot; ... I fail",
#  'tummy ache.',
#  'Math quiz: If Meow =  but Allergies =   then Meow + Allergies = ?',
#  "@hiracdelest who's the one always working now?  oh yeah, still me.",
#  "@askegg I'm sorry, Andrew. I wish there was something I could do...",
#  'as if i finsh work at eleven.. IS THAT EVEN ALLOWD?  cauz i really dont want to.. lol',
#  "@AmandaMallard i'm not at chaseton's either  please don't die, my heart will be really sad",
#  'that was an interesting show to say the least. recap tomorrow. first i must sleep. work in am.',
#  "@pastorpeterko Hey Peter, thanks for the follow. So many Sydney pastors tweet!!! Shame no Bris pastors are on Twitter; we're behind.",
#  'aku kbangun gara2 mimpi @manyolitha, very bad dream',
#  "I can't sleep, this is so darn frustrating.",
#  '@stormyamorette just one of those days where loneliness creeps up on you slaps you in the face.',
#  'RIP kelly  fucccccck',
#  'Not feeling too good',
#  'Ok. Time to nodd off its gonna be a long day tomorrow. Saying goodbye to my car for good',
#  'i miss oklahomaaaaa  listening to citizen cope til i pass out.',
#  "its funny. i'm kinda sad on my last day",
#  "Jenny fell asleep and didn't come over",
#  'Wishes you had teased me with movie night',
#  "@johneast I've missed one this year(!). It's the forbidden fruit. Of all the trees in the garden I munch in disappointment on that one.",
#  '@IvanaE i love it to.. but i knw there gna cut stuff out on tv',
#  '@JoannaAngel I do  But Im on a strict diet. . . ugh I feel like if i cheat for one day Ill throw everything up.',
#  "So Cal Dachshund Rescue found a home for my foster pup, Max. I'm soooooo sad to see him leave",
#  'wow I feel like ish  and I really feel bad because those ignorent aholes wont overturn prop 8',
#  'off to work now, finish about 9pm  booooo.',
#  "Wishes you hadn't teased me with movie night",
#  'maybe i should take up drinking again, feel as if i have a ,massive hangover  still not ,yself today',
#  'should be sleeping.  lost my voice a couple day ago.',
#  'I was too sleepy earlier and i didnt get to see matt',
#  'I just realized I spelled &quot;adorable&quot; wrong when I tweeted @mindykaling she must hate me now',
#  'how to have a glowing face? my complexion is always so pale',
#  "Downloadfestival's lineup isn't as good as i thought it was. There are some other awesome bands doing the festivals, but missing DL",
#  'So wish the Carlton game was on live  stupid channel 7 lol.',
#  '@Sashairene hahaha oh man please come to pomona i would love to see you everyday instead of like once a year if that',
#  'oh no my tweetdeck is malfunctioning :O il have web will its fixd',
#  "@ElectraX ...i'm sorry about you are still sick  u know most of them, AND i know that u will guess the &quot;pelzer present&quot; ;-)",
#  '@maliciousmandy1 Adam Samberg + new moon trailor = good evening. Too bad my cable is off as of friday',
#  'Just got my ass kicked in Tripoly lol  I got such bad cards... i suck',
#  'Annnnnnddd another one bites the dust',
#  'on my 42nd written fuck.. i get less ideas every day, and every day',
#  '@hammett I wish I could have time for my xbox  project all tied',
#  'Wow. That hurt way worse than i thought it would.',
#  'And trash repops.  Getting it tomorrow night I suppose.',
#  "feels like crap whenever she lays down. @)(1+-'$#! I hate heartburn &amp; backaches!",
#  "@katiefreeze I miss you!!!! It's lonely and empty without you!  http://yfrog.com/3o3zxoj",
#  '@lozzyx NOICE. I realised that after exams I have 2 more weeks  Forgot about the whole 2 weeks of Unit 4 in term 2 thing :/',
#  'Missing Everyone',
#  "My sisser is moving tomorrow and of makes me sad  actually I guess technically in a couple of hours since it's already Friday.",
#  'No churchill downs for me tomorrow',
#  'Bahh the police ended the party @ 5!!  Just when i was starting....',
#  '@wired that is so sad',
#  "@Jordalynn omg you've never seen 'the Ring' its a creppy ass movie",
#  'mannnn..... @alllyy_ got an iphone!!! im jealous....',
#  'is still sick  sigh',
#  'Josh just called me a big bucket of ugly  wish me luck for my audition tweets!',
#  'i feel really weird',
#  "@future_perfect I'm trying to self learn photoshop but it's not going so well!",
#  'my throat hurts  gonna go read and go to bed. text mee!',
#  'fjdskal im really frustrated.',
#  'Wondering how come mcdonalds take so long to deliver my food.',
#  "@desdoulas Ya, the weather has been super weird here. It looked like it was gonna rain today but of course it didn't, darnitt,",
#  '@kenyaimagine ... much more injustice than we can imagine now. It will get worse before it gets better, I am afraid. No doubt here. Sorry',
#  "Sooo.....I'm kind of sick n tired of the bs that guys dish out  !!!!!!!!",
#  '@StarOnMaineSt idk lol my head hurts. rly bad. &amp; so does my stomach... hmm... personally, i think its from all the #s ive had 2 deal wit',
#  'FUCK wasting deodorant... i aint goin no where... i aint havin company  let me funk it to ya!',
#  "what a beautiful day - shame I've got to spend it in an office",
#  'Just finished watching the series return of the Chasers War on Everything - really quite crap compared to how it used to be',
#  "Wow just realized haven't checked Twitter since 9am when I saw my to-do list. Good news- got lot done. Bad news-don't know where day went",
#  "http://twitpic.com/664b7 - miss my bestfriend :'( now she left school",
#  'OUCH! my earphones just shocked me',
#  'Tummy hurts',
#  'farewelling an employee tonight...',
#  "Morning all. The water heating's packed up, so i can't have a bath. I REALLY want a bath!",
#  '@heavenlyriot Girls are confusing.',
#  '@ lyrically_Me   Why would you do that to me?!',
#  'Blackout in the city is never good',
#  "@wedplanworkshop . Flights already booked, plus its GGD2 1st birthday. Can't miss that ! especially as we missed GGD1",
#  '@half_a_mind Chris and I are staying in Glasgow instead cause there is absolutely no accomodation in Edinburgh due to the marathon',
#  '@t_isfortammy Sad tweets are sad',
#  "Have decided I just can't stand @GuyKawasaki's Alltop spam any longer.",
#  'i miss rich',
#  'Headache of the century coming- I can feel it  Fuck.',
#  'disappointed to know that I got the Silver Award. I want the GOLD award. I hate being second best.',
#  'home from ice cream tweet-up (my very first tweet-up!) No pics because my camera battery died last night and i forgot to charge it',
#  '@narain Dun wanna travel all the way there for lunch now. But yeah i have been there. Nice place. Missing Shan-e-Punjab though...',
#  '@xMyLifesAStoryx rob got lucky that game he beat me 209-205',
#  "Bah I don't think @bing's FB fan page will get to 7500",
#  'home from school had the shitest day today',
#  '@hobosexual lol.  When I went to buy my new laptop in Feb., I already knew, lol, but I looked anyway and walked away sadfaced. :/',
#  'Sitting by myself. Everyone took the good seats.',
#  "@sfannah Ahhhhh  Well at least I'm up to!",
#  '@DHughesy ME! oh wait wrong state',
#  "It's fucking cold here north now! It was like 77 DF yesterday where I was, here it's 37,4",
#  'Are u missing ur frnds ? Hear to &quot;Manasellaam &quot; From Kulir100 Degree movie. Its amazing !!!  Nanbargale - Miss u guys !!!',
#  'Sorry was that mean',
#  'Dogs eyes seem bad. Just forked out on new washing machine so why not a vets bill to top it off eh?!?!',
#  '@rscheuer sorry, is only in spanish for the moment',
#  '@cha_rade oh no the economy gotcha?  sorry but so happy that you got another one in LA!  Enjoy SoCal! Ahahaay! LOL',
#  'has had the flu pass unto me by andy...went shopping and got fresh chicken for chicken soup...but no d&amp;d this sat ...is a sad panda',
#  'not well',
#  '@Miss_Rain oh what the hell  way to tell me.',
#  '@theblackestsea oh crap!!',
#  'so carlie came over and she fell asleep on me',
#  "@shaundiviney i didnt get the msg!! :'( but i bought princess",
#  "@movewithme lol ik they are, but i figure i've kept it for a year+ without needing virus software or to get it fixed  sigh",
#  "I'm so unhappy being here. I hate it. It's affecting everything. My relationships with people, my personality, my attitude...",
#  "There's Nothing To Do Right Now And I'm Tired But I Don't Want To Sleep. Cleaned Up Pretty Good, So Proud. At Least I'd Be A Good Janitor",
#  '@Madush oh my... now im offended.  ha',
#  'The 3d version of Up sold out   regular version it is!',
#  "@NickTheIntern my love!!! We still havn't done lunch together like we said we would.. I miss you my friend",
#  "To all my friends: Im deeply sorry i'm moving, i will miss u all so very very much!",
#  'Where is my bestie when i need him @iAmcertiPHIed',
#  '@allyycase suuure',
#  "now aches &amp; chills have joined the party. Why couldn't the cold just go away? It had to get worse?",
#  'bed. with stomach ache',
#  "lappy charger is completely dead... conserving what's left of the battery until i can afford to buy a new one",
#  'finally accepting the fact that all cute guys are taken',
#  "Summer Glau to appear in Dollhouse next year http://tinyurl.com/mnrezc... I still can't believe they won't renew TSCC",
#  "@HazelAngeli @V0TR0N  too bad Vo got me sick I think  &amp; I don't even have meds to feel like you.",
#  "Honza takes his flight back to the Czech Republic in the morning  I'm really going to miss him.",
#  'ah thats better snow patrol! now to be stuck indoors  still weekend coming up and fresh air excellent hope its sunny!',
#  '@FriendlyFetus cause they changed man....',
#  'up early again  loads to do- but the suns out, hurrah!',
#  '@BevJack Babes it was sooo much fun!!  Thank you so much for making that happen!  Had fun with the ladies too!  Time went to fast.',
#  'Matty is le tired.',
#  '@NellaGrl not really having a good night... missing my little girl...',
#  'Nite Tweeple.  Tomorrow will be day 25 at work.',
#  'Ahh man up and getting ready for work  I wanna sleep!!!',
#  '@JasmineCJones  I was just thinking the same thing! I love our morning chats! We totally need 2 live 2gether full time. Lol',
#  'Wish I was at sri panwa now',
#  'wants to listen to musiq soulchild, but it is not on the iPod',
#  'i miss seeing fireflies.....',
#  "@Brookeleeadams hang in there- health should be priority #1 right now! i do hate seeing good people get mistreated so i'm genuinely sorry",
#  '@ColeDavid had  a little family party tonight   hope it rocked',
#  "Had a awesome time 2. Got2meet brandon rhyder! Unfortunatly i can't sleep n tomorrow.  back 2 the ole job. @pattymlt got my game face on!",
#  '@Saresa And I feel your pain.',
#  "My Pandora is hitten hard, why can't real radio play great music like this",
#  '2orw!!!!! Nooooooo I want to go back to Newcastle!!!!',
#  "bout to watch notorious cause that's how i'm feelin now. wish i could eat something, but i can't.  surgery tomorrow. no food til saturday",
#  'Where are all you Motivated/Determined/wannabe sexy successful young professionals!??! I might really have to join a BNI if there is no1!',
#  '@Jessicaveronica you guys gonna tour with Short Stack again? I missed your last tour  Me friend went and said it was mad!',
#  '@hudaaaa eeeeeeeeeeeeee i jealous sia i didnt get to seee',
#  "arrrgh. i'm bored. so bored. there's nothing to do except slouch at the computer all day long.",
#  "I'm going to miss Miss Suhana",
#  'Why are the sinks in hospital toilets so low? Now the crotch of my grey suit is spattered with water! Just in time for Physio',
#  "@mandy2610 and @esko yea, just confirmed that this game indeed is already patched...  LOL guess you'll have to help me tomorrow ;)",
#  'Gonna go watch Shorty Street &amp; then prison break marathon then bed maybe. Nobodies texting me!',
#  "I should go get a life. Sam just texted me 'Phuture tonight?'  http://sgBEAT.com/pic/81/",
#  'sad that will have to leave my beautiful apartment',
#  'gonna dream about my prince charming tonight, n see if everything goes back to normal. I really hope so   &lt;3',
#  'wow i have no friends on twitter',
#  "@greco31 I've been trying not to think about that!",
#  'Waiting on the bus! I miss my car',
#  "says I'm still dreaming about that Nikon D60..erRr!  *ate, kuya **PLEASE** lang* huhuh http://plurk.com/p/wxrx5",
#  'It is kind of lonely when nobody will answer their phone.',
#  'Rest In Peace  ADaM 12 &amp; GLeNN EPPS.... Gone but never forgotten... what a week ...Loud in da air 4 ya',
#  'is having the worst week, things really do happen in threes',
#  '@katrinalmoreno and im an idiot for missing their last show',
#  '@Katarinea Oh wow  ouch...',
#  '@ruthchu wat the! you were in riverside??',
#  '@chuybe. you left me first .. and left your bed here for me to look at',
#  'Bike trail - 1, Miss J - 0, two front teeth - 1 1/2.. Hopefully! Vacations suck!',
#  'Sadly I am bprohibiting myself from tweeting tonight. Sorry',
#  '@kesoleil Oh man, Did Yogg today. Worse than last week.',
#  "@anant25121986 it is so unfair that all the good rock shows happen only in B'lore and Pune",
#  '@sydthekid why are you sad?!',
#  "I miss the concert Tuesday already. I'd really like a time machine to go see it again... It was so fun...",
#  'cant sleep again! I couldnt sleep last night eather!  *Wabble Wabble*',
#  "hahaha yeah i see that. but he can't twitter me back",
#  'have to stay away from home, and since this part of india dnt hav gud wireless internet, im fucked',
#  'Wookei why did you never accept my psn friend request',
#  '@davidaKaplan As do I  Leopold says hello.',
#  'because my dad has the tv to loud. Then i get creeped out cuz im from a dodgy neighbourhood and there was someone in my bush.',
#  'cant talk very well, just remembering about something once said to me...  not a good thing fucking bully nasty pieces of work arrrrgrrrrrr',
#  '@tiataquito you stop it',
#  "Watching Jay Leno's 2nd last Tonight show   I haven't gone a day without Leno in like four yearss.",
#  'just got home.. downtown was dead.. plus im kinda under the weather and i gotta get up for work tomorrow',
#  'Yesterday a friend of mine was thrown off his horse as a lorry drove past us, ignoring us signaling for him to slow down',
#  'Ready to go into work now.  cannot be bothered.',
#  "I hate working nights, cos I'm not really able to enjoy this gorgeous weather, as I will be asleep",
#  'i really should stop relying on my family when they say their going to get me lunch',
#  "Changed my hairstyle,but it isn't good as it supposed to be N don't wealth that much money..  hate that hairdresser~~",
#  '@niccoqp I miss going to EK every summer &amp; christmas vaca  Take me there!',
#  '@_erica I know right',
#  '@roshnimo yup .. sad eh .. Betty man .. it should have been betty',
#  'they shot him  he was still alive too...',
#  '@polyap POL! Is this song from a new album? I am really missing out on UdD!',
#  'is tired of summer already',
#  'feels really sick.',
#  "@runhipporun just took the Terminator trilogy :-D but what I need is actually TV series and I still can't find anything tempting",
#  "@Trentskers Pfftt... I wish. Don't have time though.",
#  '@assembled ive been there before  haha',
#  "Mom asking if I'm feeling better after dargah visit. Dad swears he sees +ve &quot;change&quot;.  I am amused.   But yeah, still depressed",
#  'Their songs make me want to cry..',
#  '@AshleyGofficial aww dont cry ashley',
#  "Oops, they don't open until 9am",
#  'My siblings left me alone.   Bored. (:|',
#  "i have the biggest headache right now, i washed my hair wif mum's shampoo and now it's gross  i like my shampoo way better",
#  'In the bus... Almost an hour late because of my crappy alarm clock  should be in Leeuwarden at about 9:45',
#  'I wish my grandmother had taken me to the US with her',
#  '@noiselesssound I just heard that Regina girls song @ les deux! And I think u should/have 2 come back 2 mc! I miss u',
#  'bummed i didnt get to see manchester orchestra bc it was sold out, i spent all night buying tv shows on itunes  lame',
#  '@valdivia1 what about me?',
#  'Well thats me for the day, watching Panthers tonight beat the Saints (fingers crossed) cause there are no QLD teams playing this round',
#  "@Krista_Watson I can't this weekend, sorry  And Steph is working.",
#  'Heading home now, yay! Was going to buy a much needed bottle of wine to drink with dinner, but my wallet is MIA so no wine for me tonight',
#  'just got home. im so effin sad',
#  '@lizz_xx cheer up lizzi there will b another foh hero concert   but still i suppose we can b upset  xoxoxo',
#  "@zackintoys Sadly, it doesn't  I was so hopeful after American Doll Posse, too ... it's just so blah and vacant of dynamic.",
#  "@MommaSalty ...that's a miserable afterparty report",
#  'Not excited of blowing out another candle today... [as when I was a kid!]',
#  "sigh....it's always so sad when you watch the series finale....no more green wing left to watch",
#  'I tried to dye my hair and all i got was a blond chunk in the front middle part of my hair. Dang.',
#  'Got the BrainBone daily question wrong!  - http://bit.ly/11dd2T',
#  "The fam back on the Big Island said the vog has been so bad that they can't see the ocean. Sad!",
#  "NOOOOO! serena and darrian don't remember each other, and i've been waiting all day to see them confess their love",
#  'A sunny morning in the Big K, with lawns to mow and a 2 mile to run to attempt, urgh',
#  '&quot;locked up abroad&quot; makes bein half brown good risk mgmt when travelin 3rd world. i blend. i feel sorry for my hostage magnet white pepo',
#  '@bskeete87 THEN Y R U LEAVN???? STAY!?',
#  "@destinyeyes i'm sorry! lol i have never had, like, actual time to spend there unfortunately. everything's always been INSANE when i go",
#  "@Potato_Chip That's right! I totally forgot. Might not be till August, though    Have a great summer!!",
#  '@USOuljah Ohh Emmm Geee. Souvlaki from Dimitris...I wanna go homeeee  LOL',
#  'Wants milk',
#  '@madeleinelaurin whys your cat in pain?',
#  'aww my poor tank friend.    his guild is fucking him over after promising him main OT. he barely even gets to go now.  ;_;',
#  '@franksting yeah... it is very very dry down here',
#  'god it pisses me off that i always enter comps &amp; never win.I am such a sore loser',
#  'Canï¿½t stop loosing.  Worst month results ever... Bubble two times in a row.',
#  'I was awake until 12:45am then my mum turned the internet off so i couldnt watch the @jonasbrothers live chat i was ccrying i was sad',
#  'Time for bed, oh how I wish someone was laying next to me',
#  '???-?? ? youtube ? ????',
#  "@captainboots  YOU'RE FAKING IT! Hahaha...I kid.",
#  '@mzstokes No twitpic?  lol',
#  '@DSTROYR @RockDaMullet awwww i have no internet right now....  -drummer boi',
#  'Today is going to be a normal day for I hope. We had a group of pilots from a large airline come in last night so it was too much drink',
#  'OMG sore shoulder',
#  '@irkengir No. As a result, the salary is a decrease',
#  "Can I get tonight's SYTYCD online anywhere...streamed like Hulu or paid like iTunes. I missed my favorite judge and now I can't sleep.",
#  "I feel sick..like don't wanna get out of bed, be bothered, don't go 2 work, turn da light off, pull da shades n tv off type of sick",
#  "@yelainez  oist the 1st tym, di pa ko 18, the 2nd tym, may sakit na siya... don't blame me",
#  "Why don't we close the library due to the great weather?  And the ac isn't working  #fb",
#  'Time to do house chores! Ugh!',
#  "getting ready for school.. reading what's going on on set in Montepulciano, and practically crying cause i'm not there",
#  '@pourmecoffee I won my 5th grade spelling bee. Went down trailing flames on 1st word at county spelling bee  http://post.ly/geb',
#  "missing Taylor like crazy  cant wait till he's back",
#  'Had a good day till he twisted his ankle on his two mile run',
#  "Can you believe it:Tomorrow Night will be Jay Leno's last episode of the Tonight Show  I encourage everyone to watch it and welcome Conan.",
#  'Bing! no its not Chandler Bing, its the new Search engine from Microsoft http://tinyurl.com/mgcotd ..but why the name Bing',
#  'aw got orthodontist today',
#  '@TerrenceJ106 yooo! Its rainin dumb hard out.',
#  "Changed my hairstyle,but it isn't good as it supposed to be~~N I don't think it wealthed that much money..  hate that hairdresser~~;(",
#  '@J2thaESSICA yeah dnt go there.. I have 3 dif apps on my phone for it  so sad but there is a reason as to why lol',
#  'Um k.. this is NOT Close My Eyes.. this song always makes me cry bc my mom is gone but I &lt;3 it anyway..',
#  '@SmellTheCheese I know, that is so sad.  I',
#  "Bought a new combo printer at costco today (officejet j4550) cause it was cheaper than ink 4 old one. #windows7 doesn't like the fax part",
#  'why do i have to wake up so early goddam?! 7.30 on my last day off  bummer',
#  '@LouGagliardi  damned hordies',
#  "@dj_cm  Didn't drink enough for a hangover, just tired and over worked",
#  'my cheeeks hurt so bad. what happened!?',
#  "Just awoke in a completely freaked out frantic frenzy.  It's going to be a long night.",
#  "where's enthusiasm in meeeee",
#  "@kim_flores aww i don't! i guess that's why it doesnt  (blackberrymessenger)",
#  'drinking some really nice coffee, got to go to the dentist at 9am this morning',
#  "looks like my ION-based mini-itx board won't ship until mid-June now at the earliest",
#  '@jessereed did u watch the day the earth stood still? did u not see my bye when u got d/c...  im sad i left 2 and now ur gone  ily&lt;333',
#  "@tifftiff88 what don't be sad?  Be glad. Your 21",
#  '#DepecheMode concert next week cancelled  Alternative date not known yet. Dave Gahan had a tumor.',
#  "its 2:08 am. I CAN'T SLEEP!!!!!  i thought it was b/c im hungry, so i whipped up a pb&amp;j with milk. hopefully it works!!!!",
#  'Only 1 tweet in the last 24 hours?  Nobody likes my tweetboard',
#  "i'm so bored i can barely even tweet. i have nothing to talk about.  #boredboots",
#  'my head is killing me, i keep sneezing, and i think my boyfriend fell asleep. greaaat',
#  'roughnight',
#  'Tired. About to climb into bed and fall asleep. I hope this weekend will be fun... I only have a couple of weeks left',
#  'Bad day, just got worse...',
#  '@irkengir It is a recession',
#  "Headache from last night has morphed in to a hangover  and now it's time to drive down the motorway... to Wolverhampton (WHY OH WHY?!)",
#  '@Meikah Hala, I do not know that one.  Shame on me.',
#  'Goodmorning yall! I woke up to early',
#  '2moro is the end of my stay @Grandmas to bad shes in NY Then off 2Ft Laud 4a weddin Florida is fun but i miss Home and Spike(car) lol',
#  "@godfatherobie  I'm @ work and missed everythin yesterday but don't know wot? Anybody",
#  'fell asleep waiting for my ride!',
#  'Today feels like friday. Too bad its not',
#  'now im gettin a complex my followers are shrinking   want to make 100 b4 Sunday',
#  "Fun game of 'Candamir' with the kids last night. Can't believe it's now our last day",
#  "Has been underpaid  just when i really didn't need to be as well.",
#  '@Adamastorlx ohyeahhh  hate the heat!  http://twitpic.com/665a2',
#  '@sashaostrikoff i miss you',
#  'Feeling bad that @muemerry didnt get to see UP',
#  "Disappointment really sucks!  I'm getting used to it.",
#  "Getting rather annoyed at my notebook. I know it's old and has got wrinkles but it's never been this slow before",
#  '@_C_A_S_ IM MAD IT WASNT SCAREY',
#  '@SharktailYPP The red font up the top is very nice. But where did they put all the old entries?',
#  '@deezeen I know, pero available na yata eh. Sa Singapore, though!',
#  'Season 1 of Lie To Me was serious. Damn, now here comes the wait.',
#  'i mean monday take the test monday!!!! please o please !',
#  "@SummerXoxo That's exactly how I feel.  I hope you start feeling better soon.",
#  'My birthday is now over.',
#  'at work and tired just want to go to bed',
#  'feeling so dizzy right now',
#  '@msalonen I feel like a Truck just hit me too! I also Resemble a man hit by a truck!',
#  '@ZDAEfron and @hudgensness why are u two fighting.',
#  "@ahhrjay useless tweet! LOL jk yay!!! You're coming tmr! How long u gnna be in phils for  ?",
#  "@Jazzy813 I miss my neice  can't wait to see her bad n grown ass! Lol",
#  "Holy shit it's super sunny, Friday and Whitsun, my tube is deeeesearted. Wish I was in the park  http://tinyurl.com/ns2l55",
#  'I am soo happy! But frustrated at the same time!  :]  :S. Ohh noo!!! Britney is recording her new video for Radar!!!  Sooo ExxCiiTeed!!!',
#  "BOOYA!! Sup Tweeps!? Happy inFAMOUS day to you all, off to get it very soon. Can't wait to play, need to find some more time though",
#  "@TerrenceJ106 I'm up wit cha!! Just got home from da reggae club, wishin I was sexin somebody!!!",
#  "Ugh talk to me someone  I'm really bored.",
#  'Sleeping on the streets of nyc for a celebrity...nothing new. Wish i had a huge blanket though',
#  'have a splitting headache!',
#  'OMG. Period cramps are FTL. So much pain.',
#  '@shortstackband grrrrrrrrrrrrrrrrrrrrrrrr',
#  'I thought that there was going to be another Def Jam Fighting game, but then it turned out to be crappy karaoke game. I miss the fighting',
#  'Using tiffys computer...it feels different from mine... the touch is different.',
#  'Bummed out I am missing a rock climbing trip next week',
#  'Stuck in some shitty traffic! This day is going to be crap',
#  '@Maccah Red? wtf happened to dark blue + black stripes?',
#  'sick to my stomach.. and i have a headache.. i wish someone could come rub my temples.',
#  "Not a good start to the day left my money at home . So i'll hot a day me looking for free carparks",
#  "@deathnerd ah man, that's sucks.  What happened to it that's prompting a reinstall?",
#  "@Farctum Oh poor thing  Hope it's easily sorted out. (and not too expensive!)",
#  'my stupid msn wont sign in',
#  "Ship. I'm stuck.",
#  '@Lil_maggie you okay? i miss you @tanyadenalilove im sad you didnt text todayh',
#  '#3wordsaftersex it hurts now',
#  "Heavily medicated but can't sleep. Ugh...",
#  "Grrrrr fuck. Just remembered that I'm doing the later shift today, so not at work for another hour! What a wasted lay in opportunity",
#  'Is dreading going to work  BUT....its friiiiiday!! whoop!!!',
#  '@DontLetGo14 at home  im so lonely here...',
#  "what is love!? baby don't hurt me, don't hurt me, no more. I WANT TO WATCH 'NIGHT AT THE RUXBURY' RIGHT NOW!!!!",
#  "blast from the mofo'ing past. NTS why must you suck so badly at school?",
#  'Its too early',
#  'wowza, only the second tweet of my entire trip and i leave in 3 days   but first - BLOW UP SF TOMORROW NIGHT!',
#  'My computer is being killed by a combo of mirrors edge and really poor win7 thermal management...75c gpu = one sad game',
#  '@serenetan Is it? Wah. Wasted trip!',
#  "@Kingsrockandrol I'm a bit down zoe cos I'm off to bed soon, so I will miss this gorgeous weather, were having  what you up too today? X",
#  "Lots of confusions I've at my work place..",
#  'My tummy hurts  go away cramps! I hate chuu!!!!',
#  "I wanna go to DBSK oppa's Mirotic Concert in Thailand!!! I REALLY WANNA GO SO MUCHHHHH...    *burst into tears*",
#  '@rettema &quot;might be interested&quot; - thanks, I was: I came, I saw, I winced..  too much like Flatland http://bit.ly/12f0y',
#  "i lost my voice . what should i do ? it's very torture",
#  "it's pretty cold outside  today i got another exam...",
#  "I'm a genius  put rug in washing machine, left folding door half open, machine moved now door won't close or open. shaking head.",
#  '@Lmhustle4life Shit none. But yea last weekend was crazy, i think i partied to hard, thats why im sic.',
#  '@itstayloryall Im so sad we missed you at Family Reunion!!',
#  "@absolutelytrue  #nightshift I'm still working  luckily having fun with it. I can turn the music up when no one else is in the office. yay",
#  '@1825remnant, i missed everyone tonight',
#  'Ugh our two week push to produce a six pack has produced nothing but pain!',
#  'ooh i feel so sleepy... its 10:24 a.m. and i dont wanna go to school 2day  but i have to...',
#  "@love2reed thx girl! I just now woke up! I cnt believe I'm sick!! Now I have a fever... Wish I could pound nyquil  This sucks.",
#  "@donald_jackson already there's none left  back to cabbage soup",
#  'Wrong button  ... My music biz building that is.',
#  'having the flu, not the swinish-one, but the flu.',
#  'really annoyed that work appear to have blocked facebook now...',
#  'its friday!  well, technically anyway...but its really thursday for me.  dang having to work saturday mornings',
#  '20 mins from BEJ to Semanggi. Traffic on Friday  *siggghh*',
#  '@AyeBloodyRight Taking the souls of your friends and family and watching them die is a nightmare. Trust me',
#  "@Emsy Yeah, mine said &quot;That's a nice picture&quot; &amp; gave me the red x!  Hope you get it working soon!",
#  'missin my bro..',
#  '... A kidney stone. Really?? Ugh  http://tinyurl.com/qsw9vq',
#  '@DarynJones Your youtube account is down.',
#  '@sueveeyall Haha, I wish I could',
#  "@jlynn242001 ur there when I'm not  lol",
#  'still sick  @ Home http://loopt.us/iArPRg.t',
#  'not feeling too great today',
#  'Warwick Castle http://snurl.com/izzau Amazing!  Off to Devon for a week...no internet, no updates',
#  'i hate that feeling you get when you listen to a song and it completely reminds you of how things used to be &amp; you get emotional',
#  'you ever come across something that reminds you alot of the one person that completely broke your heart? cause i just did',
#  'Ria got a a G1 phone and im jealous',
#  'my party is wiped out they be all dead and stuff',
#  "@Branwen6277 I'm better today.  Yesterday was really hard.  It's still just so unbelievable.  I miss him, too... and probably always will.",
#  '@AmandaSevasti Ugh, frustrating. I see a few briefs a week with groups in them, mostly from traditional agencies.',
#  '@BrandyWandLover Oh I see who u mean now-tht heltershelter person lol. yer looks scary',
#  'good morning people !! in good old germany is it soooo cold',
#  '@sunnyphoenix there was like no1 there n tha DJ comp was hella wack... no gud DJs  but got in free so its all gud',
#  'is lonely in need of company',
#  'WTF? Advertising gone mad, they want access to my  camera and microphone? What for? Amazon should really know better  http://bit.ly/5FoKQ',
#  'i hate it when a website says the ticket prices are on another website and their not',
#  "alice doesn't know what to wear to the cinema  &lt;3",
#  "I don't think I am going to get to see any of the sun today  gutted I NEED COLOUR!",
#  "@dameenrouge I have been to Tara Thai a few times for friend's birthdays and the food I had was pretty bad.",
#  'wow i must have been tired. i fell asleep @ exactly the start of the 10pm news &amp; now up as if its 8am.',
# ...
#  'very tired and anxious',
#  'I chilled in my room with my baby book missed my bro leavin  he really is cool had a stripper shirt on said I suppoort single moms! Funny',
#  "its my burfday and i'm all alone",
#  '@JoelMadden I applaud you for accepting gay marriage, I have rels that are born again that hate me for it.',
#  'Headache',
#  '@Alma773  want somebody to hold me Alma! tear tear',
#  "@ELJmcfly I don't think any of what i just said it true, i just had a rant about mcfly, i cant belive i did that  i feel ashamed",
#  'Its beginning to get way too hard to please all of my friends at once',
#  "yea dude... 5'8&quot;! really!?",
#  '@MrDeNiro i wish someone would inspire me with some sexy time right now ugh but thats not gonna happen...  ugh',
#  'not in the mood',
#  "I'll miss the 39th floor view...",
#  "now i'm awake i can't get back to sleep",
#  'Now i feel really really bad...sorry',
#  'Sleep....take two....this better work!',
#  '@elmers10 miss u more',
#  "@HellenBach the geek, the stepson and the live in nanny love BGT, me - can't stand it!  Had to watch TV upstairs all alone!",
#  'Enjoying the nice couple dad with my brother to bad we never really see each other anymore...',
#  "Just got finished watching marley and me, and I cried like a fucking baby...I'm missing my beast like crazy!",
#  'My phone passed away yesterday.. He jumped off the table  Searching for a new phone...',
#  'oh my god. my twitter feed has been taken over by geeky stuff! @bmw @brampitolo @kodinlanewave @kenkeiter so funny! I wish i understood',
#  'nobody loves me on twitter',
#  "@iAmNauj can't.  wish I was sleeping. Gotta be at work in less than 4 hours... Wait, what're u doing up???!",
#  '@iSpyLevis nooooooooo i just got into my pyjamas!',
#  "@liedra Bubble tea is awesome, it's been so long since I've had some",
#  "@Rina_spn your boyfriend didn't even say bye!",
#  "Have you ever realized you never fully have everything you want?  feelin' down.",
#  'Gutted, been invited to a bbq tomorrow night, gonna miss the BGT final   ...Wonder if they can wheel the TV outside??',
#  '@jerseyzmorenita: Sad But True  :: I SHouldnt Right?',
#  'supposed to be great weather today &amp; 2moro; just my luck Im stuck in work 1-10 both days!',
#  "i lost all my friends, i'm alone and sleepy..i wanna go home",
#  '@brainstuck i didnt get the joke',
#  "Also, I'm really missing Sami... just thought I would throw that one out there...",
#  'what a lovely summery morning! Shame I have to be in work!!!!',
#  '@ACALLPRO -- yeahhh u wasnt thereeeeeeeeeee',
#  'i REALLY miss my photofiltre and photoscape  GIMP is too damn confusing',
#  'at last i wr0te again....got bored the previous dayss....',
#  '@halina1979 what sun?',
#  "@binncheol  I'm afraid so. All tour I have had people refusing to believe that I am anything else... Irish all the way.",
#  "It's 4 am and I'm hungry",
#  'Why do weddings on TV make me cry? Is it just my inner desire to be eternally happy and start the rest of my life??',
#  "can't go to bed  An am sooooo tired!!!",
#  "man.. it's starting to rain real hard..",
#  "can't believe he has to wait till October to see &quot;Up!&quot; when Americans get to see it this weekend.",
#  "@sebchew YoYo door nazis refused me entry on account of no ID  gutted! Heard it was a good night tho.. Next time I'll come prepared!",
#  "Just wrote lyrics to my new song exciting!I slept on a full stomach again it's the worst feeling waking up and still feeling full  euggh",
#  '@DeadMemoriesX Poor you   If I was with you right now; I would probably give you a hug ;D',
#  'got paid nowhere near as much as she thought she would',
#  "Wow one year today Luc Bourdon was killed, doesn't seem that long ago",
#  'Wow what a sunny day,  just recovering some erased files',
#  '@rmilana Hey, Wahts happening in #coffeclub..? I didnt have coffee for two days now  @dharshana',
#  'I have not been this sick in years. OMG. This sucks so bad. Sickness ended up including a full restroom cleanup.',
#  '@swpave ?????????????',
#  '@pilgrimfamilyuk oh no I hate that',
#  'How I wish I get at least 2 days-off in a row. 1 day off is not enough to rest.  3 days on, 1 day off, 4 days on, 1 day off...Ugh!!!',
#  '@hojomo im having trouble finding really yummy egg free ice-cream   #favoriteicecream - got any recommendations anyone?',
#  'Did a historical Jesus ever exist? Im finding it hard to prove, its all hearsay accounts ... it bugs me ...',
#  "I guess you're not talking about Orlando Magic @whoiskenan! There was nothing magical about it",
#  "I never thought falling in love can cause so much pain...  good thing that I'm so over that phase!",
#  'is wondering where all her friends went...',
#  '@MarkK_H when you wake up, tweet me and let me know when ur on msn. I really need to talk to you  miss you',
#  '@libbyoliver caught tweets on it and got home in time for the last 5 mins of the ITV2 show!! #bgt Out tonight too so will miss it again',
#  "The Good: I drank Jager and licked a hot asian girl's foot. The Bad: I was reminded once again that I will never get asian girls ever.",
#  '3 hours sleep last night, all of my being wants to crawl into a ball somewhere and sleep for about 5 more hours. At work till six too',
#  'i thought it was already winter. turns out winter has even started',
#  '@mangointhesky idk. The original is so great.',
#  'Finishing Homework.  BOOO',
#  'Is so freaking bored on the bus. Hate being poor, ï¿½4.80 return for a 10 min train or ï¿½2 return for an HOUR long bus.ipod has no battery 2',
#  '@BK_II I have no choice  have to get on it!',
#  'Football session after this.fun',
#  'lost all my files since high school.',
#  'job centre bound. oh yay.',
#  '@hilsatlvsonline Thanks for the tip! Unfortunately a major crash in my https site, just as ExtPlorer',
#  '@moneymakn1 Thats actually not that fun as you would think... I was hurting for a week after a similar experience.',
#  '@FelipeAzucares Everyone seems to love it, but it felt kinda lazy and repetative to me.  I was really disappointed.',
#  "Its a lovely day sky is clear birds are singing and i'm stuck in an office with on windows for 9 hours",
#  'Not ah huge fan of getting up in the middle of the night to change peed sheets and underpants.',
#  'nothing could get worse, or could it? if it did i think id be on the verge of killing myself or someone else, things are not good anymore',
#  'todays weigh in....  only lost 1/2 pound this week :o depressing',
#  '@shaundiviney 04182012154 send me one PLEASE!! I TXTD IN BUT I GOT A NEW PHONE',
#  '@SASHAMINAJ lol   the things u gotta do sometimes man smh lol',
#  "@sophiatam haha yea! Just working and chillin in the eastbay. Unlike u, I don't get a summer break  boo",
#  '@papermelody although these are a BIT tighter (smaaaaller) than my last pair, they were baggy as hell, now I get front wedgies',
#  '@MarkStanto why thx! #webdu I was only at the conf on Thurs',
#  'Aww I heard I just missed you two @logieo &amp; @egg104 !',
#  'writing report cards  soooo tired but what an amazing day. check it out on fb soon!',
#  'Damn, got Chili Beans on my shirt  I hate that I can be a messy eater. Such a lady!',
#  "@JeremyRylan I'm on mobile web and it won't let me  it looks awesome though....and no one reads my tweets anyway.",
#  '@dave_mueller yes i love it  its just a little bit complicated, because i want it on my BB , but it doesnt work',
#  "i'm so sad, because my beloved boy doesn't online, i wait for him everyday..",
#  '@DaveDeRoo hardly :/ some of my furniture is being shipped from who knows where and is backordered  I may cancel and shop local.',
#  'huh? its 1 am already? shucks',
#  "bwarg. can't sleep, tired of drawing.",
#  "Don't have time to chat (sorry girls  Miss y'all!), but we have a new lawnmower... yeah, that was today's highlight. Tomorrow is...",
#  '@pyroezra i really wish i could.',
#  "@Nelja exactly like that ...in glasgow now ...it's a bgt busier",
#  "Can't wait to come home! I miss my Bubba. Too bad my parents are taking him to Canada.",
#  'laughed so much today over that picture of lauren, that my chest hurts.',
#  "I'm SAD SAD SAD!!! thought my aunty Stina coming but no more  i was so looking forward to having family..i miss dat! i'm alone on maui",
#  "Arghhh...my korean dvd can't see..I need to laugh..",
#  'has to do two 50 page assignments this weekend  there goes any chance of relaxation!!',
#  'Town. Uncle and Gabriel are coming in. I miss Gabe  Tempted to ask if I can go back to Baton Rouge with and stay with other side of fam...',
#  "@amberndragt  There isn't any right now. They need to make more. Sorry.",
#  'lost my BA115 enlisted class in CRS!! ( whyyyy. hindi naman conflict or whatever.  ang labo ng CRS grabe. T.T',
#  '3rd day of pain',
#  'missed out on westcott micro apollo too',
#  'Dad: &quot;No trips to Lahore for you.&quot; Me: &quot;I do live in DC &amp; NYC which also = big targets.&quot; Bummer, no Pizza Hut chicken tikka pizza for me',
#  'Last night I had 1/2 a bottle of wine in my house and 2 cocktails. Came home sober but still gonna be sick',
#  '@DatDoodRace Thts kinda young 4 me, boo.',
#  'Weather is back to being great! Shame I have to wait in for my delivery',
#  '@Jonasbrothers movie out today but i cant go see it',
#  '@HoneyJune k... i guess i cant help it.... byeee 4eva....  (m really sad)',
#  'I hate the &quot;out-of-nowhere&quot; stuff...',
#  "sick n tired of people who steal other people's work",
#  '@SeandBlogonaut daddy wanted to buy me shoes, but they were prettie esspensive, so nao I haff to go bearfoot',
#  'Is too much of a bro',
#  'back at work  its too warm to be in here today!!!',
#  'Lobbying in twitter! Here too!!  Yuk! Gettin rid of groupies ;)',
#  '@davidmarkscott another letter for you - this one car insurance - ouch',
#  'Went to the Athletics Carnival today! Tired, very tired! I hurt my back when I jumped for the second time on the High Jump!',
#  'its too sunny for work  !!!',
#  'boys and girls lie? awww is santa not real either?',
#  '@oliviamunn that was pretty lame babe',
#  "@rawrgoesaimee Ah bibisita ka kina GQ bukas o  sasama ka sa Rushers EB? I won't be able to visit Jumpstart tom coz I have something to do",
#  'i miss my daddy',
#  '@lisaxjbx3 Goodnight is not on the trending topics.  lol',
#  'owww i think i tore something in my leg',
#  "I can't believe how fast this week has gone by",
#  '@Beckinelson idkk if il get to see it again',
#  'Bah day is not ending as nicely as it began',
#  "Already 26.1c in our office. Can people melt? We're fighting for air con because fans just don't help, but can't find the budget",
#  "@iamdiddy I don't think they sale Ciroc where I stay..Damn..thats just my luck",
#  '@ferretwho Defeated by a Polo',
#  "@violetbakes My friend is a massive Beatles fan, and she wasn't impressed",
#  "Nevermind! Beyonce doesn't have a Twitter  Haha",
#  "@jesssicababesss really? cuz KC.com said it was releasd 24/4 here n the main station doesn't even hav it",
#  "@kathtrinder @samscam what's that? The sun? No sign here",
#  '@Emiily_Kate i know its heaps awesome. if your not working all weekend',
#  "@mistermagnus A friend uses Logic and I must admit I did like it...but I don't have a Mac",
#  '@caldjr yeh me 2',
#  "It's too hot to be sat in an office!  I wanna be out in the sun shineeeee.",
#  "Just got Skyfire (http://get.skyfire.com/).  Firts impressions, it looks good but it's a little too memory hungry for my ageing HTC TyTN",
#  '@oOogabriela wat u doin my bad im mixin this song',
#  '@BlueEyed_Cat @himynameisrose we all know and yes dont remind me im so effin jealous  fuck aust some times',
#  'Is now crying  Omg I am fed up with this pain !!!',
#  "@atlprincess 'erocka the ruler' i called you, but i see i gets the no love   whats up with that?",
#  "I'm up way to early today!  Work later.",
#  'im really tired.. not much time to sleep',
#  "@ncremins Wednesday? you are joking me? that soon???  when's the partaaaaaaay?",
#  "@codemonkeyism there were attempts to somehow extend inner classes, which would be close to #closure, can't find the ref ATM",
#  'sad day!!!!! Love you Maï¿½ (8 years ago!)',
#  "Is going to get a full nights sleep tonight so her arm can get better. It's no fun being forced to use your left hand",
#  '@jennytalia SHUT YOUR FACE! Why are you so mean to me? Pedro is supposed to be the mean one',
#  '... and itï¿½s FFA *evil grin* but Iï¿½m so busy at work today I wonï¿½t get anything done',
#  'Fell down the stairs at dancing, sword fell on me and now my bum hurts',
#  '@wethedan nope, would be no music',
#  '@MAVinBKK it feels like ages away! More than 5 months',
#  '@JustDarline DArLiNE!!* miss you',
#  "Why didn't I book today off as well could not be bothered with work the weather is too good to be in here",
#  '@ncremins thats not really fair. I mean you just up and leave like that and you dont even give us a party  So when you coming back or  ...',
#  "I hereby proclaim it to officially be summer as it is AWESOME today! But I'm stuck inside a chilly office",
#  "sleeping... would've been home sooner but we accidentally killed bambi on the way home",
#  'had the lovliest night last night but was ruined by doctors inability to warn me of side effects. back again for more tests.',
#  'Woke up and there was sun! And then it started to rain',
#  '@tahninial just called me a cheeseburglar. He made me sad',
#  'Getting bored sitting at the hotel room the entire day',
#  'Uuu, am din nou PR 4. Yeey, my epenis is now bigger! ... ... ...',
#  "Bumping Air Supply's Greastest Hits",
#  "can't believe I'm peeling from one and a half days of sunshine",
#  '@k_tron oh god, whose tire?',
#  'Will be flying to Ontario in 4 hours!Will probably stay awake.I will be there for a 8 days...Camping 4 the first time YAY!I am sleepy now',
#  'is going back home  love ya Zagrebe &lt;3',
#  'has just booked her appointment to give blood 18:20pm 2nd June! Scared',
#  'staring at the sunshine through my office window!',
#  'I wish I had a concept of what time it is right now....  not adjusting well. Obvs.',
#  "getting dressed to go to Granny's,another day of now twitting",
#  'Feeling pretty poo today',
#  'I wanna go to the beach...but I have to study',
#  "What's worse than a fever and sore throat? Cancelling a trip to see your little bro because of a fever and sore throat.",
#  "On a brighter note.. still at work at 6:15 on Friday working on other peoples problems...  oh man. I'm SO eating pizza tonight. hoorah!",
#  'just reached for her plate to get another bit of toast and realised id eaten it all  not a nice feeling',
#  'geez why do u have to be SO obvious?',
#  'i messed up my back/hip. it hurts so bad',
#  '@jolynnchew so early??',
#  "Had a crazy night, lost keys, walked home, missed my papi's calls from the swizzy.    I'm sad",
#  '@vmysterrr are you serious!? that bloooooows',
#  "Mooorning! It's Friday, and that's terrific! Smile up!    :-|      :-D",
#  'Going to bed...going back to Korea tomorrow',
#  'missed the #jonaswebcast',
#  'At millys having some yummy asian food! Haha. And listening to let go, such a sad song',
#  'my blog is crashing my browser',
#  'My mind is playing tricks or me!...or could it be? Either way this ish is on my mind heavy and in sleepy',
#  '@LaylaNatalie nowhere babe  ice come to do a few jobs here this morning *sigh*',
#  "@terryronald When does it close? I didn't think it'd been running that long? I still haven't had chance to see it!",
#  '@ladybug8320 oh yes i sure will, but sad cause i will miss the view at the house am leaving actually',
#  '#liesboystell Your the only one, I love (they really have several women)',
#  '@NANCY___ just got your TWEETS. that sucks my love',
#  'sadly awake. wondering about contact info for all of the fun folks I hung out with at the shop. YAY 23b!!! Miss you guys',
#  "@realchrissystar we'll be back sunday to play @ the horse, I was out last night at mex you were not  miss you",
#  "@LivLaughLove7 u didn't hit me up",
#  'fuck elora danan are breaking up  too and im missing their last nsw show too  def need to hit up melbs !! someone come with ?',
#  'I guess its bedtime. Goodnight twitter.  my bed is so big and empty without him.',
#  ...]

# %%
labels_list = df.sentiment.tolist()

# %%
labels_list
# Out:
# ['sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anger',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'anger',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'anger',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anger',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'anger',
#  'surprise',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'happiness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'anger',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'happiness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'happiness',
#  'anger',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anger',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'anger',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'anger',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'anger',
#  'happiness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'happiness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'surprise',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'surprise',
#  'happiness',
#  'happiness',
#  'surprise',
#  'happiness',
#  'sadness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'surprise',
#  'surprise',
#  'surprise',
#  'surprise',
#  'sadness',
#  'surprise',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'sadness',
#  'happiness',
#  'happiness',
#  'surprise',
#  'sadness',
#  'sadness',
#  ...]

# %%
emotions_list_plutchik = ['anger', 'anticipation', 'digust', 'fear', 'joy', 'sadness', 'surprise', 'trust']

# %%
negations_list = ['never','no','nothing','nowhere','noone','none','not','havent','hasnt','hadnt','cant',
                  'couldnt','shouldnt','wont','wouldnt','dont','doesnt','didnt','isnt','arent','aint',
                 'wasnt']

negations_list.extend(["haven't","hasn't","hadn't","can't","couldn't","shouldn't","won't","wouldn't",
                       "don't","doesn't","didn't","isn't","aren't",
                        "wasn't"])

# %%
def handle_negations(tokens):
    new_tokens = []
    prev_neg = False
    for token in tokens:
        current_token = token

        if prev_neg == True:
            current_token += "_NEG"
            prev_neg = False

        if token in negations_list:
            prev_neg = True

        new_tokens.append(current_token)
    return new_tokens

# %%
# universal_tags_keep = ['VERB', 'NOUN', 'ADJ']
# VERB (verbs), NOUN (nouns), PRON (pronouns), ADJ (adjectives), ADV (adverbs), ADP (adpositions ), CONJ (conjunctions), DET (determiners), NUM (cardinal numbers), PRT (particles ), . (punctuation) and X (other).

# %%
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
def custom_tokenizer(text):
    # Tokenize text
    tokens = tokenizer.tokenize(text)
    
    # Handle negations
    tokens_neg = handle_negations(tokens)
    
    # POS tagging
    tokens_tagged = pos_tag(tokens, tagset='universal')
    
    tokens = [ (tokens_neg[i],tagged) for token in enumerate(tokens)]
    return tokens

# %%
def custom_preprocessor(text):
    # Remove URLs
    text = re.sub(r'http\S+|https\S+', '', text)
    return text

# %%
vectorizer_options = dict(
#     min_df = 0.1,
#     max_df = 0.7,
#     stop_words = 'english',
    
    lowercase = False,
    tokenizer = custom_tokenizer,
    preprocessor = custom_preprocessor,
    ngram_range = (1, 2),
#     binary = True
)

# vectorizer = CountVectorizer(**vectorizer_options)
vectorizer = TfidfVectorizer(**vectorizer_options)

# %%
def create_featurevector(documents):
    tfidf_matrix = vectorizer.fit_transform(documents)
    return tfidf_matrix, vectorizer

# %%
train, vectorizer = create_featurevector(text_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-9c180936b1c9> in <module>
# ----> 1 train, vectorizer = create_featurevector(text_list)
#
# <ipython-input-26-032bcda85f2c> in create_featurevector(documents)
#       1 def create_featurevector(documents):
# ----> 2     tfidf_matrix = vectorizer.fit_transform(documents)
#       3     return tfidf_matrix, vectorizer
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1611         """
#    1612         self._check_params()
# -> 1613         X = super(TfidfVectorizer, self).fit_transform(raw_documents)
#    1614         self._tfidf.fit(X)
#    1615         # X is already a transformed view of raw_documents so
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in fit_transform(self, raw_documents, y)
#    1029
#    1030         vocabulary, X = self._count_vocab(raw_documents,
# -> 1031                                           self.fixed_vocabulary_)
#    1032
#    1033         if self.binary:
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     941         for doc in raw_documents:
#     942             feature_counter = {}
# --> 943             for feature in analyze(doc):
#     944                 try:
#     945                     feature_idx = vocabulary[feature]
#
# ~\Anaconda3\lib\site-packages\sklearn\feature_extraction\text.py in <lambda>(doc)
#     327                                                tokenize)
#     328             return lambda doc: self._word_ngrams(
# --> 329                 tokenize(preprocess(self.decode(doc))), stop_words)
#     330
#     331         else:
#
# <ipython-input-23-59b883bd6b96> in custom_tokenizer(text)
#      10     tokens_tagged = pos_tag(tokens, tagset='universal')
#      11
# ---> 12     tokens = [ (tokens_neg[i],tagged) for token in enumerate(tokens)]
#      13     return tokens
#
# <ipython-input-23-59b883bd6b96> in <listcomp>(.0)
#      10     tokens_tagged = pos_tag(tokens, tagset='universal')
#      11
# ---> 12     tokens = [ (tokens_neg[i],tagged) for token in enumerate(tokens)]
#      13     return tokens
#
# NameError: name 'i' is not defined

# %%
train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-5e6a15ce28a5> in <module>
# ----> 1 train.shape
#
# NameError: name 'train' is not defined
